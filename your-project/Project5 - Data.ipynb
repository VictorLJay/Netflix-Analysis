# %%
# Libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
import re
from datetime import datetime as dt

# %%
# Importing Netflix DF
netflix = pd.read_csv("../data/Netflix_Titles.csv", )
netflix = netflix.drop(columns=["show_id", "description"])
netflix["date_added"] = pd.to_datetime(netflix["date_added"])
netflix["date_added"] = netflix["date_added"].dt.strftime("%Y-%m")

# Importing IMDB DF
IMDB = pd.read_csv("../data/IMDb_results_nov-22-2020.csv", index_col=0)

# Joinig both tables
netflix = netflix.join(IMDB)

# Cleaning the DF mantaining the desired columns
netflix = netflix.drop(columns=["IMDB_titleID", "IMDB_title_name"])
netflix = netflix.rename(columns={"IMDB_rating":"IMDb_rating"})

# %%
netflix
# Out:
#          type                                        title  \
# 0       Movie      Norm of the North: King Sized Adventure
# 1       Movie                   Jandino: Whatever it Takes
# 2     TV Show                           Transformers Prime
# 3     TV Show             Transformers: Robots in Disguise
# 4       Movie                                 #realityhigh
# ...       ...                                          ...
# 6229  TV Show                                 Red vs. Blue
# 6230  TV Show                                        Maron
# 6231    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# 6229                       NaN
# 6230                       NaN
# 6231                       NaN
# 6232                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...                                                 ...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6231                                                NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country date_added  release_year  \
# 0     United States, India, South Korea, China    2019-09          2019
# 1                               United Kingdom    2016-09          2016
# 2                                United States    2018-09          2013
# 3                                United States    2018-09          2016
# 4                                United States    2017-09          2017
# ...                                        ...        ...           ...
# 6229                             United States        NaN          2015
# 6230                             United States        NaN          2016
# 6231                                       NaN        NaN          2016
# 6232                            United Kingdom        NaN          2013
# 6233                             United States        NaN          2003
#
#         rating    duration                                          listed_in  \
# 0        TV-PG      90 min                 Children & Family Movies, Comedies
# 1        TV-MA      94 min                                    Stand-Up Comedy
# 2     TV-Y7-FV    1 Season                                           Kids' TV
# 3        TV-Y7    1 Season                                           Kids' TV
# 4        TV-14      99 min                                           Comedies
# ...        ...         ...                                                ...
# 6229        NR  13 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230     TV-MA   4 Seasons                                        TV Comedies
# 6231       NaN      60 min                                             Movies
# 6232     TV-MA   2 Seasons           British TV Shows, TV Comedies, TV Dramas
# 6233     TV-14  10 Seasons                     Classic & Cult TV, TV Comedies
#
#                             IMDb_rating
# 0         3.2 based on 294 user ratings
# 1          5.0 based on 21 user ratings
# 2       7.9 based on 5,331 user ratings
# 3         6.0 based on 830 user ratings
# 4       5.2 based on 5,496 user ratings
# ...                                 ...
# 6229    8.3 based on 8,840 user ratings
# 6230    7.7 based on 4,530 user ratings
# 6231       6.1 based on 19 user ratings
# 6232   7.9 based on 14,452 user ratings
# 6233  8.9 based on 802,016 user ratings
#
# [6234 rows x 11 columns]

# %% [markdown]
# ##### MANERA PARA ENCONTRAR TODAS LAS VECES QUE SALE UN PAÍS

# %% [markdown]
# Done

# %%
netflix_test_usa = netflix[netflix["country"].str.contains("United States", case=False, regex=False, na=False)]

# %%
netflix_test_usa
# Out:
#          type                                    title  \
# 0       Movie  Norm of the North: King Sized Adventure
# 2     TV Show                       Transformers Prime
# 3     TV Show         Transformers: Robots in Disguise
# 4       Movie                             #realityhigh
# 6       Movie                                 Automata
# ...       ...                                      ...
# 6225  TV Show                                  Frasier
# 6226  TV Show                      La Familia P. Luche
# 6229  TV Show                             Red vs. Blue
# 6230  TV Show                                    Maron
# 6233  TV Show                                  Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# 6                  Gabe Ibáñez
# ...                        ...
# 6225                       NaN
# 6226                       NaN
# 6229                       NaN
# 6230                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6     Antonio Banderas, Dylan McDermott, Melanie Gri...
# ...                                                 ...
# 6225  Kelsey Grammer, Jane Leeves, David Hyde Pierce...
# 6226  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country date_added  release_year  \
# 0     United States, India, South Korea, China    2019-09          2019
# 2                                United States    2018-09          2013
# 3                                United States    2018-09          2016
# 4                                United States    2017-09          2017
# 6       Bulgaria, United States, Spain, Canada    2017-09          2014
# ...                                        ...        ...           ...
# 6225                             United States        NaN          2003
# 6226                             United States        NaN          2012
# 6229                             United States        NaN          2015
# 6230                             United States        NaN          2016
# 6233                             United States        NaN          2003
#
#         rating    duration                                          listed_in  \
# 0        TV-PG      90 min                 Children & Family Movies, Comedies
# 2     TV-Y7-FV    1 Season                                           Kids' TV
# 3        TV-Y7    1 Season                                           Kids' TV
# 4        TV-14      99 min                                           Comedies
# 6            R     110 min  International Movies, Sci-Fi & Fantasy, Thrillers
# ...        ...         ...                                                ...
# 6225     TV-PG  11 Seasons                     Classic & Cult TV, TV Comedies
# 6226     TV-14   3 Seasons  International TV Shows, Spanish-Language TV Sh...
# 6229        NR  13 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230     TV-MA   4 Seasons                                        TV Comedies
# 6233     TV-14  10 Seasons                     Classic & Cult TV, TV Comedies
#
#                             IMDB_rating
# 0         3.2 based on 294 user ratings
# 2       7.9 based on 5,331 user ratings
# 3         6.0 based on 830 user ratings
# 4       5.2 based on 5,496 user ratings
# 6      6.1 based on 53,988 user ratings
# ...                                 ...
# 6225   8.0 based on 72,555 user ratings
# 6226      7.7 based on 777 user ratings
# 6229    8.3 based on 8,840 user ratings
# 6230    7.7 based on 4,530 user ratings
# 6233  8.9 based on 802,016 user ratings
#
# [2610 rows x 11 columns]

# %%
usa_testing = []

for word in netflix_test_usa["country"]:
    usa_testing.extend(re.findall(r"\bUnited States*", word))

# %%
len(usa_testing)
# Out:
# 2610

# %% [markdown]
# ##### INTENTO DE OBTENER TODOS LOS PAÍSES DE MANERA ÚNICA

# %% [markdown]
# Done

# %%
#Obtención de todos los unique values. Ahora extracción de los mismos en otra cell
countries = list(netflix["country"].apply(str).unique())
countries = [x for x in countries if x != "nan"]
#len(countries) es 554

# %%
only_first_country = []

for country in countries:
    only_first_country.extend(re.findall(r"^(.+?),", country))

# %%
countries_clean = list(set(only_first_country))
countries_clean.sort()
print(countries_clean)
len(countries_clean)
# Out:
# ['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria', 'Cambodia', 'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Egypt', 'Finland', 'France', 'Georgia', 'Germany', 'Ghana', 'Hong Kong', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Malaysia', 'Mauritius', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Russia', 'Saudi Arabia', 'Serbia', 'Singapore', 'Slovenia', 'Somalia', 'South Africa', 'South Korea', 'Soviet Union', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Venezuela']
# 64

# %% [markdown]
# ##### OBTENCIÓN TODOS LOS GÉNEROS

# %% [markdown]
# Done

# %%
genres = netflix["listed_in"].apply(str).unique()
genres = [x for x in genres if x != "nan"]
#len(genres) de 461

# %%
only_first_genre = []

for genre in genres:
    only_first_genre.extend(re.findall(r"^(.+?),", genre))

# %%
genre_clean = list(set(only_first_genre))
genre_clean.sort()
print(genre_clean)
len(genre_clean)
# Out:
# ['Action & Adventure', 'Anime Features', 'Anime Series', 'British TV Shows', 'Children & Family Movies', 'Classic & Cult TV', 'Classic Movies', 'Comedies', 'Crime TV Shows', 'Cult Movies', 'Documentaries', 'Docuseries', 'Dramas', 'Horror Movies', 'Independent Movies', 'International Movies', 'International TV Shows', "Kids' TV", 'Music & Musicals', 'Reality TV', 'Romantic TV Shows', 'Sci-Fi & Fantasy', 'Spanish-Language TV Shows', 'Stand-Up Comedy & Talk Shows', 'TV Action & Adventure', 'TV Comedies', 'TV Dramas', 'TV Horror', 'TV Sci-Fi & Fantasy']
# 29

# %% [markdown]
# #### Release Year

# %% [markdown]
# Done

# %%
# Obtener todos los valores y hacer un sort de manera descendente. 
# Ver aquellas fechas que tienen una mayor presencia (pelis/series nuevas vs antiguas)
# Agrupar por bins para categorizar

release = list(netflix["release_year"].apply(int).unique())
release.sort()
print(release)
# Out:
# [1925, 1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958, 1959, 1960, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %% [markdown]
# ##### One Hot Encoding

# %%
#PASO 1
netflix[netflix["country"].str.contains("United States", case=False, regex=False, na=False)]
# Out:
#          type                                    title  \
# 0       Movie  Norm of the North: King Sized Adventure
# 2     TV Show                       Transformers Prime
# 3     TV Show         Transformers: Robots in Disguise
# 4       Movie                             #realityhigh
# 6       Movie                                 Automata
# ...       ...                                      ...
# 6225  TV Show                                  Frasier
# 6226  TV Show                      La Familia P. Luche
# 6229  TV Show                             Red vs. Blue
# 6230  TV Show                                    Maron
# 6233  TV Show                                  Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# 6                  Gabe Ibáñez
# ...                        ...
# 6225                       NaN
# 6226                       NaN
# 6229                       NaN
# 6230                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6     Antonio Banderas, Dylan McDermott, Melanie Gri...
# ...                                                 ...
# 6225  Kelsey Grammer, Jane Leeves, David Hyde Pierce...
# 6226  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country date_added  release_year  \
# 0     United States, India, South Korea, China    2019-09          2019
# 2                                United States    2018-09          2013
# 3                                United States    2018-09          2016
# 4                                United States    2017-09          2017
# 6       Bulgaria, United States, Spain, Canada    2017-09          2014
# ...                                        ...        ...           ...
# 6225                             United States        NaN          2003
# 6226                             United States        NaN          2012
# 6229                             United States        NaN          2015
# 6230                             United States        NaN          2016
# 6233                             United States        NaN          2003
#
#         rating    duration                                          listed_in  \
# 0        TV-PG      90 min                 Children & Family Movies, Comedies
# 2     TV-Y7-FV    1 Season                                           Kids' TV
# 3        TV-Y7    1 Season                                           Kids' TV
# 4        TV-14      99 min                                           Comedies
# 6            R     110 min  International Movies, Sci-Fi & Fantasy, Thrillers
# ...        ...         ...                                                ...
# 6225     TV-PG  11 Seasons                     Classic & Cult TV, TV Comedies
# 6226     TV-14   3 Seasons  International TV Shows, Spanish-Language TV Sh...
# 6229        NR  13 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230     TV-MA   4 Seasons                                        TV Comedies
# 6233     TV-14  10 Seasons                     Classic & Cult TV, TV Comedies
#
#                             IMDB_rating
# 0         3.2 based on 294 user ratings
# 2       7.9 based on 5,331 user ratings
# 3         6.0 based on 830 user ratings
# 4       5.2 based on 5,496 user ratings
# 6      6.1 based on 53,988 user ratings
# ...                                 ...
# 6225   8.0 based on 72,555 user ratings
# 6226      7.7 based on 777 user ratings
# 6229    8.3 based on 8,840 user ratings
# 6230    7.7 based on 4,530 user ratings
# 6233  8.9 based on 802,016 user ratings
#
# [2610 rows x 11 columns]

# %%
# PASO 2
netflix_test_usa[["listed_in"]].unstack().str.get_dummies(sep=", ").sum(level = 0).rename(index={"listed_in":"United States"})
# Out:
#                Action & Adventure  Anime Features  Anime Series  \
# United States                 247               3             9
#
#                British TV Shows  Children & Family Movies  Classic & Cult TV  \
# United States                22                       258                 16
#
#                Classic Movies  Comedies  Crime TV Shows  Cult Movies  ...  \
# United States              61       447             115           37  ...
#
#                TV Action & Adventure  TV Comedies  TV Dramas  TV Horror  \
# United States                     73          195        189         30
#
#                TV Mysteries  TV Sci-Fi & Fantasy  TV Shows  TV Thrillers  \
# United States            44                   50         3            23
#
#                Teen TV Shows  Thrillers
# United States             20        202
#
# [1 rows x 42 columns]

# %%
# Hay que sustituir la parte de "United States" por country a la hora de hacer un for loop

# %%
#ESTO FUNCIONA PARA UN PAÍS, REPLICARLO PARA MÁS
def dummy_country_genre(df, country):
    country_1 = df[df["country"].str.contains(country, case=False, regex=False, na=False)]
    
    return country_1[["listed_in"]].unstack().str.get_dummies(sep=", ").sum(level = 0).rename(index={"listed_in":country})

dummy_country_genre(netflix, "United States")
# Out:
#                Action & Adventure  Anime Features  Anime Series  \
# United States                 247               3             9
#
#                British TV Shows  Children & Family Movies  Classic & Cult TV  \
# United States                22                       258                 16
#
#                Classic Movies  Comedies  Crime TV Shows  Cult Movies  ...  \
# United States              61       447             115           37  ...
#
#                TV Action & Adventure  TV Comedies  TV Dramas  TV Horror  \
# United States                     73          195        189         30
#
#                TV Mysteries  TV Sci-Fi & Fantasy  TV Shows  TV Thrillers  \
# United States            44                   50         3            23
#
#                Teen TV Shows  Thrillers
# United States             20        202
#
# [1 rows x 42 columns]

# %%
def dummy_country_genre_test2(df, country):
    
    """
    Input: Dataframe, list of unique countries
    
    Output: The function returns a SUM one-hot encoded of the genres that appear per country
    """
    
    list_of = []
    for c in country:
        country_1 = df[df["country"].str.contains(c, case=False, regex=False, na=False)]
        df2 = country_1[["listed_in"]].unstack().str.get_dummies(sep=", ").sum(level = 0).rename(index={"listed_in":c})
        list_of.append(df2)
          
    result = pd.concat(list_of).fillna(0).astype(int)
    
    return result

dummy_country_genre_test2(netflix, countries_clean)
# Out:
#                       Action & Adventure  Children & Family Movies  \
# Argentina                              3                         2
# Australia                             10                        16
# Austria                                0                         0
# Belgium                                9                         4
# Brazil                                 3                         3
# ...                                  ...                       ...
# United Arab Emirates                   3                         3
# United Kingdom                        59                        24
# United States                        247                       258
# Uruguay                                0                         0
# Venezuela                              0                         0
#
#                       Classic Movies  Comedies  Crime TV Shows  Cult Movies  \
# Argentina                          1        10               4            1
# Australia                          3        14               8            1
# Austria                            0         0               0            0
# Belgium                            0        13               6            1
# Brazil                             0        11               4            0
# ...                              ...       ...             ...          ...
# United Arab Emirates               0         5               1            0
# United Kingdom                    11        67              43            5
# United States                     61       447             115           37
# Uruguay                            0         1               0            0
# Venezuela                          0         0               0            0
#
#                       Documentaries  Docuseries  Dramas  Horror Movies  ...  \
# Argentina                         6           1      27              3  ...
# Australia                        14           9      29              3  ...
# Austria                           3           0       5              0  ...
# Belgium                           5           0      33              4  ...
# Brazil                           11           2      22              0  ...
# ...                             ...         ...     ...            ...  ...
# United Arab Emirates              4           0      10              1  ...
# United Kingdom                  106          82     122             22  ...
# United States                   401         134     533            145  ...
# Uruguay                           5           0       4              0  ...
# Venezuela                         3           0       0              0  ...
#
#                       TV Action & Adventure  TV Mysteries  \
# Argentina                                 0             0
# Australia                                 1             1
# Austria                                   0             0
# Belgium                                   1             1
# Brazil                                    0             1
# ...                                     ...           ...
# United Arab Emirates                      0             0
# United Kingdom                            6             3
# United States                            73            44
# Uruguay                                   0             0
# Venezuela                                 0             0
#
#                       TV Sci-Fi & Fantasy  TV Thrillers  \
# Argentina                               0             0
# Australia                               2             2
# Austria                                 0             0
# Belgium                                 1             0
# Brazil                                  1             0
# ...                                   ...           ...
# United Arab Emirates                    0             0
# United Kingdom                          3             3
# United States                          50            23
# Uruguay                                 0             0
# Venezuela                               0             0
#
#                       Stand-Up Comedy & Talk Shows  Anime Series  \
# Argentina                                        0             0
# Australia                                        0             0
# Austria                                          0             0
# Belgium                                          0             0
# Brazil                                           1             0
# ...                                            ...           ...
# United Arab Emirates                             0             0
# United Kingdom                                   1             0
# United States                                   27             9
# Uruguay                                          0             0
# Venezuela                                        0             0
#
#                       Classic & Cult TV  Korean TV Shows  Anime Features  \
# Argentina                             0                0               0
# Australia                             0                0               0
# Austria                               0                0               0
# Belgium                               0                0               0
# Brazil                                0                0               0
# ...                                 ...              ...             ...
# United Arab Emirates                  0                0               0
# United Kingdom                        6                0               0
# United States                        16                2               3
# Uruguay                               0                0               0
# Venezuela                             0                0               0
#
#                       TV Shows
# Argentina                    0
# Australia                    0
# Austria                      0
# Belgium                      0
# Brazil                       0
# ...                        ...
# United Arab Emirates         0
# United Kingdom               0
# United States                3
# Uruguay                      0
# Venezuela                    0
#
# [64 rows x 42 columns]

# %%
countries_genre_encoded = dummy_country_genre_test2(netflix, countries_clean)
#countries_genre_encoded.to_csv("../data/contry_genre_encoded.csv")

# %% [markdown]
# ### Test Merge con DF de Plataformas de Streaming

# %%
netflix_test_merge = netflix

# %%
netflix_test_merge.head()
# Out:
#       type                                    title                  director  \
# 0    Movie  Norm of the North: King Sized Adventure  Richard Finn, Tim Maltby
# 1    Movie               Jandino: Whatever it Takes                       NaN
# 2  TV Show                       Transformers Prime                       NaN
# 3  TV Show         Transformers: Robots in Disguise                       NaN
# 4    Movie                             #realityhigh          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# 0  United States, India, South Korea, China    2019-09          2019
# 1                            United Kingdom    2016-09          2016
# 2                             United States    2018-09          2013
# 3                             United States    2018-09          2016
# 4                             United States    2017-09          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                        IMDB_rating
# 0    3.2 based on 294 user ratings
# 1     5.0 based on 21 user ratings
# 2  7.9 based on 5,331 user ratings
# 3    6.0 based on 830 user ratings
# 4  5.2 based on 5,496 user ratings

# %%
streaming_platforms_movies = pd.read_csv("../data/StreamingPlatforms_Movies.csv", index_col=0)
streaming_platforms_movies = streaming_platforms_movies.drop(columns=["Language", "Runtime", "Directors", "Genres", "Type", "IMDb", "Rotten Tomatoes", "ID", "Country"])
streaming_platforms_movies.head()
# Out:
#                             Title  Year  Age  Netflix  Hulu  Prime Video  \
# 0                       Inception  2010  13+        1     0            0
# 1                      The Matrix  1999  18+        1     0            0
# 2          Avengers: Infinity War  2018  13+        1     0            0
# 3              Back to the Future  1985   7+        1     0            0
# 4  The Good, the Bad and the Ugly  1966  18+        1     0            1
#
#    Disney+
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
streaming_platforms_series = pd.read_csv("../data/StreamingPlatforms_TV_Shows.csv", index_col=0)
streaming_platforms_series = streaming_platforms_series.drop(columns=["IMDb", "Rotten Tomatoes", "type"])
streaming_platforms_series.head()
# Out:
#               Title  Year  Age  Netflix  Hulu  Prime Video  Disney+
# 0      Breaking Bad  2008  18+        1     0            0        0
# 1   Stranger Things  2016  16+        1     0            0        0
# 2       Money Heist  2017  18+        1     0            0        0
# 3          Sherlock  2010  16+        1     0            0        0
# 4  Better Call Saul  2015  18+        1     0            0        0

# %%
netflix_test_merge.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# 0  United States, India, South Korea, China    2019-09          2019
# 1                            United Kingdom    2016-09          2016
# 2                             United States    2018-09          2013
# 3                             United States    2018-09          2016
# 4                             United States    2017-09          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                        IMDB_rating
# 0    3.2 based on 294 user ratings
# 1     5.0 based on 21 user ratings
# 2  7.9 based on 5,331 user ratings
# 3    6.0 based on 830 user ratings
# 4  5.2 based on 5,496 user ratings

# %%
full_netflix = pd.concat([streaming_platforms_movies, streaming_platforms_series])
full_netflix = full_netflix.reset_index(drop=True)
full_netflix = full_netflix.rename(columns={"Title":"title", "Year":"year", "Age":"age"})

# %%
full_netflix.head()
# Out:
#                             title  year  age  Netflix  Hulu  Prime Video  \
# 0                       Inception  2010  13+        1     0            0
# 1                      The Matrix  1999  18+        1     0            0
# 2          Avengers: Infinity War  2018  13+        1     0            0
# 3              Back to the Future  1985   7+        1     0            0
# 4  The Good, the Bad and the Ugly  1966  18+        1     0            1
#
#    Disney+
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
netflix_test_merge = pd.merge(netflix_test_merge, full_netflix, on="title", how="left")

# %%
netflix_test_merge
# Out:
#          type                                        title  \
# 0       Movie      Norm of the North: King Sized Adventure
# 1       Movie                   Jandino: Whatever it Takes
# 2     TV Show                           Transformers Prime
# 3     TV Show             Transformers: Robots in Disguise
# 4       Movie                                 #realityhigh
# ...       ...                                          ...
# 6248  TV Show                                 Red vs. Blue
# 6249  TV Show                                        Maron
# 6250    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6251  TV Show  A Young Doctor's Notebook and Other Stories
# 6252  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# 6248                       NaN
# 6249                       NaN
# 6250                       NaN
# 6251                       NaN
# 6252                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...                                                 ...
# 6248  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6249  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6250                                                NaN
# 6251  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6252  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country date_added  release_year  \
# 0     United States, India, South Korea, China    2019-09          2019
# 1                               United Kingdom    2016-09          2016
# 2                                United States    2018-09          2013
# 3                                United States    2018-09          2016
# 4                                United States    2017-09          2017
# ...                                        ...        ...           ...
# 6248                             United States        NaN          2015
# 6249                             United States        NaN          2016
# 6250                                       NaN        NaN          2016
# 6251                            United Kingdom        NaN          2013
# 6252                             United States        NaN          2003
#
#         rating    duration                                          listed_in  \
# 0        TV-PG      90 min                 Children & Family Movies, Comedies
# 1        TV-MA      94 min                                    Stand-Up Comedy
# 2     TV-Y7-FV    1 Season                                           Kids' TV
# 3        TV-Y7    1 Season                                           Kids' TV
# 4        TV-14      99 min                                           Comedies
# ...        ...         ...                                                ...
# 6248        NR  13 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6249     TV-MA   4 Seasons                                        TV Comedies
# 6250       NaN      60 min                                             Movies
# 6251     TV-MA   2 Seasons           British TV Shows, TV Comedies, TV Dramas
# 6252     TV-14  10 Seasons                     Classic & Cult TV, TV Comedies
#
#                             IMDB_rating    year  age  Netflix  Hulu  \
# 0         3.2 based on 294 user ratings  2019.0  NaN      1.0   0.0
# 1          5.0 based on 21 user ratings     NaN  NaN      NaN   NaN
# 2       7.9 based on 5,331 user ratings     NaN  NaN      NaN   NaN
# 3         6.0 based on 830 user ratings     NaN  NaN      NaN   NaN
# 4       5.2 based on 5,496 user ratings  2017.0  NaN      1.0   0.0
# ...                                 ...     ...  ...      ...   ...
# 6248    8.3 based on 8,840 user ratings  2003.0  NaN      1.0   0.0
# 6249    7.7 based on 4,530 user ratings     NaN  NaN      NaN   NaN
# 6250       6.1 based on 19 user ratings     NaN  NaN      NaN   NaN
# 6251   7.9 based on 14,452 user ratings     NaN  NaN      NaN   NaN
# 6252  8.9 based on 802,016 user ratings  1971.0  18+      0.0   0.0
#
#       Prime Video  Disney+
# 0             0.0      0.0
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             0.0      0.0
# ...           ...      ...
# 6248          0.0      0.0
# 6249          NaN      NaN
# 6250          NaN      NaN
# 6251          NaN      NaN
# 6252          1.0      0.0
#
# [6253 rows x 17 columns]

# %%
netflix_test_merge[netflix_test_merge["year"] > 0].tail(25)
# Out:
#          type                                    title director  \
# 6211  TV Show                        Kim's Convenience      NaN
# 6216  TV Show                     Rica, Famosa, Latina      NaN
# 6217  TV Show                            The Protector      NaN
# 6219  TV Show                           Liv and Maddie      NaN
# 6221  TV Show                             The Cravings      NaN
# 6222  TV Show           Star Trek: The Next Generation      NaN
# 6223  TV Show                                   Cuckoo      NaN
# 6225  TV Show                                Samantha!      NaN
# 6226  TV Show                        Murderous Affairs      NaN
# 6227  TV Show                                Lost Girl      NaN
# 6228  TV Show                                Mr. Young      NaN
# 6229  TV Show                              Psiconautas      NaN
# 6233  TV Show                                  Chelsea      NaN
# 6234  TV Show                      Crazy Ex-Girlfriend      NaN
# 6235  TV Show         The Magic School Bus Rides Again      NaN
# 6236  TV Show                                 New Girl      NaN
# 6237  TV Show                  Talking Tom and Friends      NaN
# 6239  TV Show                              Justin Time      NaN
# 6240  TV Show  Terrace House: Boys & Girls in the City      NaN
# 6241  TV Show                                    Weeds      NaN
# 6242  TV Show                          Gunslinger Girl      NaN
# 6244  TV Show                                  Frasier      NaN
# 6247  TV Show                                 Kikoriki      NaN
# 6248  TV Show                             Red vs. Blue      NaN
# 6252  TV Show                                  Friends      NaN
#
#                                                    cast  \
# 6211  Paul Sun-Hyung Lee, Jean Yoon, Andrea Bang, Si...
# 6216                                                NaN
# 6217  Çağatay Ulusoy, Ayça Ayşin Turan, Hazar Ergüçl...
# 6219  Dove Cameron, Joey Bragg, Tenzing Norgay Train...
# 6221  Park Hee-bon, Phillip Choi, Hong Wan-pyo, Choi...
# 6222  Patrick Stewart, Jonathan Frakes, LeVar Burton...
# 6223  Andy Samberg, Taylor Lautner, Greg Davies, Hel...
# 6225  Emmanuelle Araújo, Douglas Silva, Sabrina Nona...
# 6226                                                NaN
# 6227  Anna Silk, Kris Holden-Ried, Ksenia Solo, Rich...
# 6228  Brendan Meyer, Matreya Fedor, Gig Morton, Kurt...
# 6229  Guillermo Toledo, Gabriel Goity, Florencia Peñ...
# 6233                                                NaN
# 6234  Rachel Bloom, Vincent Rodriguez III, Santino F...
# 6235  Kate McKinnon, Miles Koseleci-Vieira, Mikaela ...
# 6236  Zooey Deschanel, Jake Johnson, Max Greenfield,...
# 6237  Colin Hanks, Tom Kenny, James Adomian, Lisa Sc...
# 6239            Gage Munroe, Scott McCord, Jenna Warren
# 6240  You, Reina Triendl, Ryota Yamasato, Yoshimi To...
# 6241  Mary-Louise Parker, Hunter Parrish, Alexander ...
# 6242  Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...
# 6244  Kelsey Grammer, Jane Leeves, David Hyde Pierce...
# 6247                                      Igor Dmitriev
# 6248  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6252  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                         country date_added  release_year rating    duration  \
# 6211                     Canada    2019-04          2019  TV-14   3 Seasons
# 6216              United States    2019-04          2016  TV-14   4 Seasons
# 6217                     Turkey    2019-04          2019  TV-MA   2 Seasons
# 6219              United States    2017-04          2017   TV-G   4 Seasons
# 6221                South Korea    2017-04          2016  TV-14   2 Seasons
# 6222              United States    2018-04          1993  TV-PG   7 Seasons
# 6223             United Kingdom    2019-04          2019  TV-14   5 Seasons
# 6225                     Brazil    2019-04          2019  TV-MA   2 Seasons
# 6226              United States    2018-04          2017  TV-14   3 Seasons
# 6227                     Canada    2016-04          2015  TV-14   5 Seasons
# 6228                     Canada    2019-04          2013   TV-G   2 Seasons
# 6229                  Argentina    2018-04          2016  TV-MA   2 Seasons
# 6233              United States    2017-04          2017  TV-MA   2 Seasons
# 6234              United States    2019-04          2019  TV-14   4 Seasons
# 6235              United States    2018-04          2018   TV-Y   2 Seasons
# 6236              United States    2019-04          2017  TV-14   7 Seasons
# 6237  Cyprus, Austria, Thailand    2019-04          2017   TV-G   2 Seasons
# 6239                     Canada    2016-04          2012   TV-Y   2 Seasons
# 6240                      Japan    2016-04          2016  TV-14   2 Seasons
# 6241              United States    2014-04          2012  TV-MA   8 Seasons
# 6242                      Japan        NaN          2008  TV-14   2 Seasons
# 6244              United States        NaN          2003  TV-PG  11 Seasons
# 6247                        NaN        NaN          2010   TV-Y   2 Seasons
# 6248              United States        NaN          2015     NR  13 Seasons
# 6252              United States        NaN          2003  TV-14  10 Seasons
#
#                                               listed_in  \
# 6211                                        TV Comedies
# 6216  International TV Shows, Reality TV, Spanish-La...
# 6217  International TV Shows, Romantic TV Shows, TV ...
# 6219                              Kids' TV, TV Comedies
# 6221  International TV Shows, Korean TV Shows, TV Co...
# 6222         TV Action & Adventure, TV Sci-Fi & Fantasy
# 6223  British TV Shows, International TV Shows, TV C...
# 6225                International TV Shows, TV Comedies
# 6226                         Crime TV Shows, Docuseries
# 6227                 TV Dramas, TV Horror, TV Mysteries
# 6228                              Kids' TV, TV Comedies
# 6229  International TV Shows, Spanish-Language TV Sh...
# 6233          Stand-Up Comedy & Talk Shows, TV Comedies
# 6234                     Romantic TV Shows, TV Comedies
# 6235                                           Kids' TV
# 6236                     Romantic TV Shows, TV Comedies
# 6237                              Kids' TV, TV Comedies
# 6239                                           Kids' TV
# 6240                 International TV Shows, Reality TV
# 6241                             TV Comedies, TV Dramas
# 6242                       Anime Series, Crime TV Shows
# 6244                     Classic & Cult TV, TV Comedies
# 6247                                           Kids' TV
# 6248  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6252                     Classic & Cult TV, TV Comedies
#
#                             IMDB_rating    year  age  Netflix  Hulu  \
# 6211    8.2 based on 7,592 user ratings  2016.0  16+      1.0   0.0
# 6216       5.8 based on 52 user ratings  2014.0  NaN      0.0   1.0
# 6217   6.7 based on 30,818 user ratings  2018.0  16+      1.0   0.0
# 6219    6.3 based on 6,491 user ratings  2013.0  all      1.0   0.0
# 6221       7.3 based on 55 user ratings  2017.0  NaN      1.0   0.0
# 6222   8.6 based on 98,930 user ratings  1987.0   7+      1.0   1.0
# 6223    7.3 based on 7,767 user ratings  2012.0  16+      1.0   0.0
# 6225      6.5 based on 454 user ratings  2018.0   7+      1.0   0.0
# 6226      6.6 based on 192 user ratings  2016.0  16+      1.0   0.0
# 6227   7.7 based on 28,386 user ratings  2010.0  16+      1.0   0.0
# 6228    6.1 based on 1,182 user ratings  2011.0  all      1.0   0.0
# 6229    7.3 based on 2,043 user ratings  2015.0  NaN      1.0   0.0
# 6233                          Not Found  2016.0  18+      1.0   0.0
# 6234   7.8 based on 16,510 user ratings  2015.0  16+      1.0   0.0
# 6235      6.2 based on 622 user ratings  2017.0  all      1.0   0.0
# 6236  7.7 based on 187,069 user ratings  2011.0  16+      1.0   0.0
# 6237      6.1 based on 244 user ratings  2014.0  all      1.0   0.0
# 6239      6.8 based on 172 user ratings  2011.0  all      1.0   0.0
# 6240    8.2 based on 1,359 user ratings  2015.0   7+      1.0   0.0
# 6241  7.9 based on 101,678 user ratings  2005.0  18+      1.0   0.0
# 6242    7.4 based on 2,065 user ratings  2003.0  16+      1.0   0.0
# 6244   8.0 based on 72,555 user ratings  1993.0   7+      0.0   1.0
# 6247      7.5 based on 703 user ratings  2004.0  all      1.0   0.0
# 6248    8.3 based on 8,840 user ratings  2003.0  NaN      1.0   0.0
# 6252  8.9 based on 802,016 user ratings  1971.0  18+      0.0   0.0
#
#       Prime Video  Disney+
# 6211          0.0      0.0
# 6216          0.0      0.0
# 6217          0.0      0.0
# 6219          0.0      0.0
# 6221          0.0      0.0
# 6222          1.0      0.0
# 6223          0.0      0.0
# 6225          0.0      0.0
# 6226          0.0      0.0
# 6227          0.0      0.0
# 6228          0.0      0.0
# 6229          0.0      0.0
# 6233          0.0      0.0
# 6234          0.0      0.0
# 6235          0.0      0.0
# 6236          0.0      0.0
# 6237          0.0      0.0
# 6239          0.0      0.0
# 6240          0.0      0.0
# 6241          0.0      0.0
# 6242          0.0      0.0
# 6244          0.0      0.0
# 6247          0.0      0.0
# 6248          0.0      0.0
# 6252          1.0      0.0

# %%
netflix_test_merge.isnull().sum()
# Out:
# type               0
# title              0
# director        1986
# cast             571
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# IMDB_rating        0
# year            2191
# age             3992
# Netflix         2191
# Hulu            2191
# Prime Video     2191
# Disney+         2191
# dtype: int64

# %% [markdown]
# ### Test RegEx IMDb

# %%
netflix_imdb_regex = netflix

# %%
netflix_imdb_regex.head()
# Out:
#       type                                    title                  director  \
# 0    Movie  Norm of the North: King Sized Adventure  Richard Finn, Tim Maltby
# 1    Movie               Jandino: Whatever it Takes                       NaN
# 2  TV Show                       Transformers Prime                       NaN
# 3  TV Show         Transformers: Robots in Disguise                       NaN
# 4    Movie                             #realityhigh          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# 0  United States, India, South Korea, China    2019-09          2019
# 1                            United Kingdom    2016-09          2016
# 2                             United States    2018-09          2013
# 3                             United States    2018-09          2016
# 4                             United States    2017-09          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                        IMDb_rating
# 0    3.2 based on 294 user ratings
# 1     5.0 based on 21 user ratings
# 2  7.9 based on 5,331 user ratings
# 3    6.0 based on 830 user ratings
# 4  5.2 based on 5,496 user ratings

# %%
re.findall(r"\d{1}\.", netflix_imdb_regex["IMDb_rating"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-e6f38206c8f0> in <module>
# ----> 1 re.findall(r"\d{1}\.", netflix_imdb_regex["IMDb_rating"])
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object
